# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('retail_prices_cleaned.csv')
df = df.rename(columns=({'Calendar years':'Region'}))
df.head()
# Out:
#            Region  1990  1991  1992  1993  1994  1995  1996  1997  1998  ...  \
# 0         Austria  4.90  4.57  4.99  4.97  4.58  5.18  5.42  4.37  3.97  ...
# 1         Belgium  3.27  2.92  3.05  2.78  3.42  4.88  4.04  3.98  4.19  ...
# 2        Bulgaria   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3          Cyprus  2.83  2.80  2.87  2.60  3.18  4.26  4.13  4.04  4.61  ...
# 4  Czech Republic   NaN   NaN   NaN   NaN   NaN   NaN   NaN  4.31  5.10  ...
#
#    2009  2010  2011  2012  2013  2014  2015  2016  2017  2018
# 0  6.95  6.69  8.32  8.38  8.62  8.63  7.44  5.64  6.22  6.63
# 1  5.26  5.18  6.48  6.20  6.24   NaN   NaN   NaN   NaN   NaN
# 2  3.84  3.62  4.16  3.44  3.59  3.75  3.45  3.79  4.64  4.58
# 3  5.53  5.21  6.06  6.36  6.47  6.48  5.30  5.30  5.50  5.79
# 4  5.16  5.01  6.58  7.13  7.00  6.61  5.75  6.14  6.58  7.27
#
# [5 rows x 30 columns]

# %%
# Drop soluble coffee data for separate df.
dfc = df[df['Region'] != 'United Kingdom 1']

for year in dfc.loc[:,'1990':'2018']:
    dfc[year] = (dfc[year]*100)

dfc
# Out:
# /Users/user/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#                 Region    1990    1991    1992    1993    1994    1995  \
# 0              Austria   490.0   457.0   499.0   497.0   458.0   518.0
# 1              Belgium   327.0   292.0   305.0   278.0   342.0   488.0
# 2             Bulgaria     NaN     NaN     NaN     NaN     NaN     NaN
# 3               Cyprus   283.0   280.0   287.0   260.0   318.0   426.0
# 4       Czech Republic     NaN     NaN     NaN     NaN     NaN     NaN
# 5              Denmark   381.0   367.0   379.0   348.0   445.0   557.0
# 6              Finland   298.0   272.0   246.0   194.0   273.0   397.0
# 7               France   373.0   343.0   231.0   203.0   240.0   369.0
# 8              Germany   399.0   384.0   400.0   362.0   418.0   502.0
# 9              Hungary     NaN     NaN     NaN     NaN   388.0   504.0
# 10               Italy   531.0   562.0   586.0   459.0   468.0   570.0
# 11              Latvia     NaN     NaN     NaN   184.0   221.0   388.0
# 12           Lithuania     NaN     NaN     NaN     NaN     NaN     NaN
# 13          Luxembourg     NaN     NaN     NaN     NaN     NaN     NaN
# 14               Malta     NaN     NaN     NaN     NaN     NaN   780.0
# 15         Netherlands   303.0   295.0   313.0   280.0   326.0   403.0
# 16              Poland     NaN     NaN     NaN     NaN     NaN   567.0
# 17            Portugal   412.0   427.0   495.0   427.0   438.0   624.0
# 18            Slovakia     NaN     NaN     NaN     NaN     NaN     NaN
# 19            Slovenia     NaN     NaN     NaN     NaN     NaN     NaN
# 20               Spain   362.0   350.0   350.0   279.0   276.0   445.0
# 21              Sweden   343.0   329.0   311.0   265.0   379.0   485.0
# 23               Japan  1026.0  1188.0  1262.0  1457.0  1469.0  1772.0
# 24              Norway   331.0   316.0   312.0   246.0   329.0   454.0
# 25  Russian Federation     NaN     NaN     NaN     NaN     NaN     NaN
# 26         Switzerland   483.0   436.0   452.0   427.0   450.0   632.0
# 27                 USA   297.0   281.0   258.0   247.0   340.0   404.0
#
#       1996    1997    1998  ...    2009    2010    2011    2012    2013  \
# 0    542.0   437.0   397.0  ...   695.0   669.0   832.0   838.0   862.0
# 1    404.0   398.0   419.0  ...   526.0   518.0   648.0   620.0   624.0
# 2      NaN     NaN     NaN  ...   384.0   362.0   416.0   344.0   359.0
# 3    413.0   404.0   461.0  ...   553.0   521.0   606.0   636.0   647.0
# 4      NaN   431.0   510.0  ...   516.0   501.0   658.0   713.0   700.0
# 5    481.0   496.0   492.0  ...   529.0   544.0   692.0   672.0   636.0
# 6    322.0   350.0   342.0  ...   351.0   369.0   536.0   480.0   429.0
# 7    330.0   276.0   278.0  ...   379.0   362.0   413.0   392.0   392.0
# 8    417.0   403.0   404.0  ...   475.0   476.0   510.0   474.0   565.0
# 9    462.0   389.0   375.0  ...   497.0   502.0   608.0   607.0   542.0
# 10   592.0   545.0   553.0  ...   768.0   734.0   852.0   849.0   899.0
# 11   418.0   458.0   491.0  ...   610.0   610.0   867.0   808.0   752.0
# 12     NaN   474.0   475.0  ...   516.0   537.0   781.0   709.0   660.0
# 13     NaN     NaN     NaN  ...   729.0   711.0   828.0   790.0   819.0
# 14  1195.0  1220.0  1003.0  ...  1296.0  1310.0  1481.0  1415.0  1499.0
# 15   365.0   367.0   367.0  ...   470.0   457.0   598.0   583.0   574.0
# 16   437.0   354.0   363.0  ...   349.0   364.0   414.0   416.0   392.0
# 17   592.0   504.0   488.0  ...   530.0   493.0   535.0   569.0   579.0
# 18     NaN   339.0   348.0  ...   508.0   484.0   606.0   671.0   682.0
# 19     NaN     NaN     NaN  ...   477.0   431.0   480.0   448.0   478.0
# 20   418.0   357.0   362.0  ...   416.0   392.0   442.0   447.0   453.0
# 21   396.0   435.0   441.0  ...   355.0   399.0   558.0   520.0   434.0
# 23  1524.0  1422.0  1352.0  ...   607.0   639.0   735.0   757.0   605.0
# 24   390.0   411.0   390.0  ...   402.0   448.0   578.0   548.0   505.0
# 25     NaN     NaN     NaN  ...     NaN   703.0   775.0   862.0   869.0
# 26   543.0   479.0   504.0  ...   530.0   659.0     NaN     NaN     NaN
# 27   343.0   411.0   377.0  ...   367.0   391.0   519.0   568.0   545.0
#
#       2014    2015    2016    2017    2018
# 0    863.0   744.0   564.0   622.0   663.0
# 1      NaN     NaN     NaN     NaN     NaN
# 2    375.0   345.0   379.0   464.0   458.0
# 3    648.0   530.0   530.0   550.0   579.0
# 4    661.0   575.0   614.0   658.0   727.0
# 5    643.0   585.0   494.0   503.0   530.0
# 6    431.0   390.0   367.0   410.0   424.0
# 7    377.0   311.0   326.0   340.0   368.0
# 8    572.0   518.0   505.0   534.0   549.0
# 9    486.0   416.0   431.0   483.0   483.0
# 10   885.0   748.0   745.0   767.0   812.0
# 11   689.0   657.0   646.0   669.0   660.0
# 12   655.0   606.0   608.0   629.0   640.0
# 13   792.0   697.0   724.0   756.0     NaN
# 14  1493.0  1280.0  1333.0  1405.0  1515.0
# 15   571.0   538.0   477.0   483.0   468.0
# 16   385.0   328.0   317.0   345.0   375.0
# 17   573.0   499.0   493.0   504.0   536.0
# 18   667.0   560.0   574.0   600.0   638.0
# 19   462.0   403.0   396.0   420.0     NaN
# 20   444.0   382.0   373.0   384.0   410.0
# 21   411.0   382.0   348.0   357.0   324.0
# 23   568.0   560.0   621.0   595.0   580.0
# 24   750.0   581.0   556.0   563.0   575.0
# 25   765.0   643.0   665.0   784.0   738.0
# 26     NaN     NaN     NaN     NaN     NaN
# 27   499.0   472.0   439.0   445.0   430.0
#
# [27 rows x 30 columns]

# %%
df1 = dfc.dropna()
df1
# Out:
#          Region    1990    1991    1992    1993    1994    1995    1996  \
# 0       Austria   490.0   457.0   499.0   497.0   458.0   518.0   542.0
# 3        Cyprus   283.0   280.0   287.0   260.0   318.0   426.0   413.0
# 5       Denmark   381.0   367.0   379.0   348.0   445.0   557.0   481.0
# 6       Finland   298.0   272.0   246.0   194.0   273.0   397.0   322.0
# 7        France   373.0   343.0   231.0   203.0   240.0   369.0   330.0
# 8       Germany   399.0   384.0   400.0   362.0   418.0   502.0   417.0
# 10        Italy   531.0   562.0   586.0   459.0   468.0   570.0   592.0
# 15  Netherlands   303.0   295.0   313.0   280.0   326.0   403.0   365.0
# 17     Portugal   412.0   427.0   495.0   427.0   438.0   624.0   592.0
# 20        Spain   362.0   350.0   350.0   279.0   276.0   445.0   418.0
# 21       Sweden   343.0   329.0   311.0   265.0   379.0   485.0   396.0
# 23        Japan  1026.0  1188.0  1262.0  1457.0  1469.0  1772.0  1524.0
# 24       Norway   331.0   316.0   312.0   246.0   329.0   454.0   390.0
#
#       1997    1998  ...   2009   2010   2011   2012   2013   2014   2015  \
# 0    437.0   397.0  ...  695.0  669.0  832.0  838.0  862.0  863.0  744.0
# 3    404.0   461.0  ...  553.0  521.0  606.0  636.0  647.0  648.0  530.0
# 5    496.0   492.0  ...  529.0  544.0  692.0  672.0  636.0  643.0  585.0
# 6    350.0   342.0  ...  351.0  369.0  536.0  480.0  429.0  431.0  390.0
# 7    276.0   278.0  ...  379.0  362.0  413.0  392.0  392.0  377.0  311.0
# 8    403.0   404.0  ...  475.0  476.0  510.0  474.0  565.0  572.0  518.0
# 10   545.0   553.0  ...  768.0  734.0  852.0  849.0  899.0  885.0  748.0
# 15   367.0   367.0  ...  470.0  457.0  598.0  583.0  574.0  571.0  538.0
# 17   504.0   488.0  ...  530.0  493.0  535.0  569.0  579.0  573.0  499.0
# 20   357.0   362.0  ...  416.0  392.0  442.0  447.0  453.0  444.0  382.0
# 21   435.0   441.0  ...  355.0  399.0  558.0  520.0  434.0  411.0  382.0
# 23  1422.0  1352.0  ...  607.0  639.0  735.0  757.0  605.0  568.0  560.0
# 24   411.0   390.0  ...  402.0  448.0  578.0  548.0  505.0  750.0  581.0
#
#      2016   2017   2018
# 0   564.0  622.0  663.0
# 3   530.0  550.0  579.0
# 5   494.0  503.0  530.0
# 6   367.0  410.0  424.0
# 7   326.0  340.0  368.0
# 8   505.0  534.0  549.0
# 10  745.0  767.0  812.0
# 15  477.0  483.0  468.0
# 17  493.0  504.0  536.0
# 20  373.0  384.0  410.0
# 21  348.0  357.0  324.0
# 23  621.0  595.0  580.0
# 24  556.0  563.0  575.0
#
# [13 rows x 30 columns]

# %%
# Find max and min in each row and set to list to check for total max.
lst_max = []
lst_min = []

for col in df1.loc[:,'1990':'2018']:
    s = df1[col]
    lst_max.append(max(s))
    lst_min.append(min(s))

y_lim_max = int(max(lst_max) + min(lst_max)*.2)
y_lim_min = int(min(lst_min) - min(lst_min)*.2)

print(y_lim_max)
# Out:
# 1918

# %%
def clean(data):
    data = data.transpose()
    new_header = data.iloc[0]
    new_header
    data = data[1:]
    data.columns = new_header
    data = data.reset_index()
    data = data.rename(columns={"index":"Year"})
    return data

def ico_rp_plot_all(df, graph_name):
    
    # Define Colors
    # These are the "Tableau 20" colors as RGB.  
    tableau20 = [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),  
                 (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),  
                 (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),  
                 (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),  
                 (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)]  

    # Scale the RGB values to the [0, 1] range, which is the format matplotlib accepts.  
    for i in range(len(tableau20)):  
        r, g, b = tableau20[i]  
        tableau20[i] = (r / 255., g / 255., b / 255.)  
    
    # Convert years to int64
    df.Year = df.Year.astype('int64')
    df.Year
    
    # 1. Declare fig size
    plt.figure(figsize=(10, 7.5)) 


    # 2. Remove all spines. Considered chartjunk
    ax = plt.subplot(111)  
    ax.spines["top"].set_visible(False)  
    ax.spines["bottom"].set_visible(False)  
    ax.spines["right"].set_visible(False)  
    ax.spines["left"].set_visible(False)  


    # 3. Set ticks to bottom and left only
    ax.get_xaxis().tick_bottom()  
    ax.get_yaxis().tick_left()  


    # 4. Set limits
    plt.ylim(y_lim_min, y_lim_max)
    plt.xlim(1990, 2019)


    # 5. Plot ticks
    plt.yticks(range(100, 1801, 100), fontsize=14)  
    plt.xticks(range(1990, 2019, 1), rotation=45, fontsize=14)  


    # 6. Plot tick lines
    for y in range(100, 1800+100, 100):  
        plt.plot(range(1990, 2019), [y] * len(range(1990, 2019)), "--", lw=0.5, color="black", alpha=0.3)  


    lst_regions = []
    years = df['Year']
    x_mean = years.mean()
    max_year = int(max(df.Year.values))
    min_year = int(min(df.Year.values))


    # Set list for regions and exclude year column.
    for col_name in df:
        if col_name != 'Year':
            lst_regions.append(col_name)


    # Iterate over the index, and for each region, plt the region's values against years.
    for i, j in enumerate(lst_regions):
        plt.plot(df.Year.values,
                 df[j].values,
                lw=2.5, color=tableau20[i])


        # Take the last value on the plot, adjust the coordinates, and place text
        y_pos = df[j].values[-1] - 0.5
        text = plt.text(2018.5, y_pos, j, fontsize=12, color=tableau20[i])


    # Custom title built to center on mean year
    plt.text(x_mean, 1900, f"Retail Prices - Annual Averages"  
           f", {graph_name} (1990-2018)", fontsize=17, ha="center")  


    # Custom footer text
    plt.text(1989, -300, "Data Source: http://www.ico.org/new_historical.asp"  
           "\nAuthor: Jesse Hartman (thecoffeepodcast.com/coffee-data / @coffee.data)"  
           "\nNote: Regions with data gaps were ommitted from this analysis.", fontsize=10)


    plt.ylabel('US Cents per LB', fontsize=14)


    # The magic of tightness
    plt.tight_layout()


    # Save figure
    plt.savefig(f"output_files/{(graph_name.lower().replace(' ', '-'))}-1990-2018.png", bbx_inches='tight')
    plt.show()
                
def ico_rp_plot_10yr(df, graph_name):
    # Function for 10 year retail with limits set on no Japan
    
    # Define Colors
    # These are the "Tableau 20" colors as RGB.  
    tableau20 = [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),  
                 (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),  
                 (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),  
                 (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),  
                 (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)]  

    # Scale the RGB values to the [0, 1] range, which is the format matplotlib accepts.  
    for i in range(len(tableau20)):  
        r, g, b = tableau20[i]  
        tableau20[i] = (r / 255., g / 255., b / 255.)  
    
    # Convert years to int64
    df.Year = df.Year.astype('int64')
    df.Year
    
    # 1. Declare fig size
    plt.figure(figsize=(10, 7.5)) 


    # 2. Remove all spines. Considered chartjunk
    ax = plt.subplot(111)  
    ax.spines["top"].set_visible(False)  
    ax.spines["bottom"].set_visible(False)  
    ax.spines["right"].set_visible(False)  
    ax.spines["left"].set_visible(False)  


    # 3. Set ticks to bottom and left only
    ax.get_xaxis().tick_bottom()  
    ax.get_yaxis().tick_left()  


    # 4. Set limits
    plt.ylim(y_lim_min, y_lim_max)
    plt.xlim(1998, 2019)


    # 5. Plot ticks
    plt.yticks(range(100, 1601, 100), fontsize=14)  
    plt.xticks(range(1998, 2019, 1), rotation=45, fontsize=14)  


    # 6. Plot tick lines
    for y in range(100, 1600+100, 100):  
        plt.plot(range(1998, 2019), [y] * len(range(1998, 2019)), "--", lw=0.5, color="black", alpha=0.3)  


    lst_regions = []
    years = df['Year']
    x_mean = years.mean()
    max_year = int(max(df.Year.values))
    min_year = int(min(df.Year.values))


    # Set list for regions and exclude year column.
    for col_name in df:
        if col_name != 'Year':
            lst_regions.append(col_name)


    # Iterate over the index, and for each region, plt the region's values against years.
    for i, j in enumerate(lst_regions):
        plt.plot(df.Year.values,
                 df[j].values,
                lw=2.5, color=tableau20[i])


        # Take the last value on the plot, adjust the coordinates, and place text
        y_pos = df[j].values[-1] - 0.5
        text = plt.text(2018.5, y_pos, j, fontsize=12, color=tableau20[i])


    # Custom title built to center on mean year
    plt.text(x_mean, 1700, f"Retail Prices - Annual Averages"  
           f", {graph_name} (1990-2018)", fontsize=17, ha="center")  


    # Custom footer text
    plt.text(1989, -300, "Data Source: http://www.ico.org/new_historical.asp"  
           "\nAuthor: Jesse Hartman (thecoffeepodcast.com/coffee-data / @coffee.data)"  
           "\nNote: Regions with data gaps were ommitted from this analysis.", fontsize=10)


    plt.ylabel('US Cents per LB', fontsize=14)


    # The magic of tightness
    plt.tight_layout()


    # Save figure
    plt.savefig(f"output_files/{(graph_name.lower().replace(' ', '-'))}-1990-2018.png", bbx_inches='tight')
    plt.show()

# %%
df = df1.dropna()

# %%
df1c = clean(df1)
df1c.head()
# Out:
# Region  Year Austria Cyprus Denmark Finland France Germany Italy Netherlands  \
# 0       1990     490    283     381     298    373     399   531         303
# 1       1991     457    280     367     272    343     384   562         295
# 2       1992     499    287     379     246    231     400   586         313
# 3       1993     497    260     348     194    203     362   459         280
# 4       1994     458    318     445     273    240     418   468         326
#
# Region Portugal Spain Sweden Japan Norway
# 0           412   362    343  1026    331
# 1           427   350    329  1188    316
# 2           495   350    311  1262    312
# 3           427   279    265  1457    246
# 4           438   276    379  1469    329

# %%
ico_rp_plot_all(df1c, 'Retail Price')

# %%
# Now let's look at the data from 1998 to 2018 (decade).
dfs = df.set_index('Region')
df2 = dfs.loc[:,'1998':'2018']
df2 = df2.dropna()
df2 = df2.reset_index()
df2 = df2.loc[df2['Region'] != 'United Kingdom 1']

# %%
df2c = clean(df2)
df2c.head()
# Out:
# Region  Year Austria Cyprus Denmark Finland France Germany Italy Netherlands  \
# 0       1998     397    461     492     342    278     404   553         367
# 1       1999     328    439     393     260    255     342   516         311
# 2       2000     305    358     345     229    215     283   444         281
# 3       2001     293    358     319     198    199     263   433         255
# 4       2002     286    405     309     184    207     273   457         260
#
# Region Portugal Spain Sweden Japan Norway
# 0           488   362    441  1352    390
# 1           465   323    351  1532    335
# 2           395   269    303  1292    298
# 3           387   254    254   860    286
# 4           390   258    255   813    309

# %%
ico_rp_plot_10yr(df2c, 'Decade')

# %%
# Let's remove Japan
df2c_nojapan = df2c.drop(columns='Japan')
df2c_nojapan
# Out:
# Region  Year Austria Cyprus Denmark Finland France Germany Italy Netherlands  \
# 0       1998     397    461     492     342    278     404   553         367
# 1       1999     328    439     393     260    255     342   516         311
# 2       2000     305    358     345     229    215     283   444         281
# 3       2001     293    358     319     198    199     263   433         255
# 4       2002     286    405     309     184    207     273   457         260
# 5       2003     318    492     357     213    250     318   547         320
# 6       2004     333    523     396     234    272     333   601         347
# 7       2005     377    528     428     284    275     406   613         375
# 8       2006     413    534     443     294    297     433   629         396
# 9       2007     427    576     482     325    341     469   702         445
# 10      2008     474    567     540     372    386     513   787         505
# 11      2009     695    553     529     351    379     475   768         470
# 12      2010     669    521     544     369    362     476   734         457
# 13      2011     832    606     692     536    413     510   852         598
# 14      2012     838    636     672     480    392     474   849         583
# 15      2013     862    647     636     429    392     565   899         574
# 16      2014     863    648     643     431    377     572   885         571
# 17      2015     744    530     585     390    311     518   748         538
# 18      2016     564    530     494     367    326     505   745         477
# 19      2017     622    550     503     410    340     534   767         483
# 20      2018     663    579     530     424    368     549   812         468
#
# Region Portugal Spain Sweden Norway
# 0           488   362    441    390
# 1           465   323    351    335
# 2           395   269    303    298
# 3           387   254    254    286
# 4           390   258    255    309
# 5           461   300    294    348
# 6           490   323    308    384
# 7           488   322    299    411
# 8           477   342    316    389
# 9           508   385    353    447
# 10          568   431    376    469
# 11          530   416    355    402
# 12          493   392    399    448
# 13          535   442    558    578
# 14          569   447    520    548
# 15          579   453    434    505
# 16          573   444    411    750
# 17          499   382    382    581
# 18          493   373    348    556
# 19          504   384    357    563
# 20          536   410    324    575

# %%
def ico_rp_plot_10yr(df, graph_name, l_lim, u_lim):
    # Function for 10 year with lower limit and upper limit
    
    # Define Colors
    # These are the "Tableau 20" colors as RGB.  
    tableau20 = [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),  
                 (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),  
                 (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),  
                 (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),  
                 (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)]  

    # Scale the RGB values to the [0, 1] range, which is the format matplotlib accepts.  
    for i in range(len(tableau20)):  
        r, g, b = tableau20[i]  
        tableau20[i] = (r / 255., g / 255., b / 255.)  
    
    # Convert years to int64
    df.Year = df.Year.astype('int64')
    df.Year
    
    # 1. Declare fig size
    plt.figure(figsize=(12, 14)) 


    # 2. Remove all spines. Considered chartjunk
    ax = plt.subplot(111)  
    ax.spines["top"].set_visible(False)  
    ax.spines["bottom"].set_visible(False)  
    ax.spines["right"].set_visible(False)  
    ax.spines["left"].set_visible(False)  


    # 3. Set ticks to bottom and left only
    ax.get_xaxis().tick_bottom()  
    ax.get_yaxis().tick_left()  


    # 4. Set limits
    plt.ylim(l_lim, u_lim)
    plt.xlim(1998, 2019)


    # 5. Plot ticks
    plt.yticks(range(l_lim, u_lim, 50), fontsize=14)  
    plt.xticks(range(1998, 2019, 1), rotation=45, fontsize=14)  


    # 6. Plot tick lines
    for y in range(l_lim, u_lim, 50):  
        plt.plot(range(1998, 2019), [y] * len(range(1998, 2019)), "--", lw=0.5, color="black", alpha=0.3)  


    lst_regions = []
    years = df['Year']
    x_mean = years.mean()
    max_year = int(max(df.Year.values))
    min_year = int(min(df.Year.values))


    # Set list for regions and exclude year column.
    for col_name in df:
        if col_name != 'Year':
            lst_regions.append(col_name)


    # Iterate over the index, and for each region, plt the region's values against years.
    for i, j in enumerate(lst_regions):
        plt.plot(df.Year.values,
                 df[j].values,
                lw=2.5, color=tableau20[i])


        # Take the last value on the plot, adjust the coordinates, and place text
        y_pos = df[j].values[-1] - 0.5
        if j == "Norway":  
            y_pos -= 10  
        elif j == "Cyprus":  
            y_pos += 10  
        elif j == "Denmark":  
            y_pos -= 10  
        text = plt.text(2018.5, y_pos, j, fontsize=12, color=tableau20[i])


    # Custom title built to center on mean year
    plt.text(x_mean, u_lim + 50, f"Annual Average Retail Prices in US Cents per lb, by region"  
           f", {graph_name} (1990-2018)", fontsize=17, ha="center")  


    # Custom footer text
    plt.text(1997, (l_lim - 100), "Data Source: http://www.ico.org/new_historical.asp"  
           "\nAuthor: Jesse Hartman (thecoffeepodcast.com/coffee-data / @coffee.data)"  
           "\nNote: Regions with data gaps were ommitted from this analysis.", fontsize=10)


#     plt.ylabel('US Cents per LB', fontsize=14)


    # The magic of tightness
    plt.tight_layout()


    # Save figure
    plt.savefig(f"output_files/{(graph_name.lower().replace(' ', '-'))}-1998-2018.png", bbx_inches='tight')
    plt.show()

# %%
# Plot without Japan
ico_rp_plot_10yr(df2c_nojapan, 'Decade', 1, 951)
